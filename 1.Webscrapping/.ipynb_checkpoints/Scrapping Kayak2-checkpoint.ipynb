# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import numpy as np
import datetime
from time import sleep

# %%
chromedriver_path = "C:/Users/bombi/Downloads/chromedriver_win32/chromedriver.exe"
#chromedriver_path = 'C:/Users/José/Documents/ENSAE Paris/2A/Python Pour le Data Scientist/chromedriver_win32/chromedriver.exe'

# %%
driver = webdriver.Chrome(chromedriver_path)
# Out:
# <ipython-input-20-1c934cc315a7>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver_path)

# %%
def get_airlines(soup):
    airline = []
    airlines = soup.find_all('span',class_='codeshares-airline-names',text=True)
    for i in airlines:
        airline.append(i.text)
    return airline
    
def get_total_stops(soup):
    stops_list = []
    stops = soup.find_all('div',class_='section stops')

    for i in stops:
        for j in i.find_all('span',class_='stops-text'):
               stops_list.append(j.text)
    return stops_list

def get_price(soup):
    prices = []
    price = soup.find_all('div',class_='Flights-Results-FlightPriceSection right-alignment sleek')

    for i in price:
        for j in i.find_all('span', class_='price-text'):
            prices.append(j.text)
    return prices

def get_duration(soup):
    duration_list = []
    duration = soup.find_all('div' , class_='section duration allow-multi-modal-icons')
    for i in duration:
        for j in i.find_all('div',class_='top'):
            duration_list.append(j.text)
    return duration_list

# %%
def remanier(compagnie):
    liste = []
    for i in range(len(compagnie)):
        if  ',' in compagnie[i] : 
            j= 0
            while compagnie[i][j]!=',' :
                j+=1
            liste.append(compagnie[i][:j])
            liste.append(compagnie[i][j+1:])
        else :
            liste.append(compagnie[i])
            liste.append(compagnie[i])
    return liste

# %%
def remanier_2(prix):
    liste = []
    for i in range(len(prix)):
        liste.append(prix[i])
        liste.append(prix[i])
    return liste

# %%
depart = ["PAR"]
Destinations = ["OSL"]
date_aller = ["04/01/2022"]
date_retour = ["04/08/2022"]
date_a = pd.to_datetime(date_aller)
date_r = pd.to_datetime(date_retour)
result = pd.DataFrame([])

for k in range(1): 
    new_date_a = date_a + datetime.timedelta(days = 7*k)
    new_date_r = date_r + datetime.timedelta(days = 7*k)
    date_time_a = new_date_a.astype(str)
    date_time_r = new_date_r.astype(str)
    destination = ["OSL"]
    date_aller = [date_time_a]        
    date_retour = [date_time_r]
    url = f"https://www.kayak.fr/flights/{depart[0]}-{destination[0]}/{date_aller[0]}/{date_retour[0]}"
    driver.get(url)
    sleep(15)
    
    try:
        show_more_button = driver.find_element_by_xpath('//a[@class = "moreButton"]')
    except:
        input("Please solve the captcha then enter anything here to resume scraping.")

    while True:
        try:
            show_more_button.click()
            driver.implicitly_wait(10)
        except:
            break


    soup = BeautifulSoup(driver.page_source, 'html.parser')
    compagnie = remanier(get_airlines(soup))
    total_escales = get_total_stops(soup)
    prix = remanier_2(get_price(soup))
    duree = get_duration(soup)
    df = pd.DataFrame({'Compagnie':compagnie, "Total d'escales":total_escales , 'Prix': prix, 'Duree': duree}, 
                        columns = ['Compagnie', "Total d'escales", 'Prix', 'Duree'])
    df["Destination"] = "Oslo"
    df["Distance"] = 1344
    df["Date_aller"] = 20220401
    df["Date_retour"] = 20220408
    df["Date_aller"] = pd.to_datetime(df["Date_aller"], format = '%Y%m%d') + datetime.timedelta(days = 7*k)
    df["Date_retour"] = pd.to_datetime(df["Date_retour"], format = '%Y%m%d') + datetime.timedelta(days = 7*k)
    result = pd.concat([result, df], axis = 0)
# Out:
# <ipython-input-21-699d506717d1>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   show_more_button = driver.find_element_by_xpath('//a[@class = "moreButton"]')

# %%
df
# Out:
#                  Compagnie Total d'escales      Prix        Duree Destination  \
# 0               Air France       \ndirect   \n149 €   \n2h 20min         Oslo
# 1                airBaltic     \n1 escale   \n149 €   \n8h 20min         Oslo
# 2                  Flyr AS       \ndirect   \n195 €   \n2h 25min         Oslo
# 3                  Flyr AS       \ndirect   \n195 €   \n2h 25min         Oslo
# 4     Plusieurs compagnies       \ndirect   \n115 €   \n2h 20min         Oslo
# ...                    ...             ...       ...          ...         ...
# 1115               Flyr AS       \ndirect   \n209 €   \n2h 25min         Oslo
# 1116               Flyr AS       \ndirect   \n229 €   \n2h 25min         Oslo
# 1117                   SAS       \ndirect   \n229 €   \n2h 15min         Oslo
# 1118               Flyr AS       \ndirect   \n305 €   \n2h 25min         Oslo
# 1119            Air France       \ndirect   \n305 €   \n2h 30min         Oslo
#
#       Distance Date_aller Date_retour
# 0         1344 2022-04-01  2022-04-08
# 1         1344 2022-04-01  2022-04-08
# 2         1344 2022-04-01  2022-04-08
# 3         1344 2022-04-01  2022-04-08
# 4         1344 2022-04-01  2022-04-08
# ...        ...        ...         ...
# 1115      1344 2022-04-01  2022-04-08
# 1116      1344 2022-04-01  2022-04-08
# 1117      1344 2022-04-01  2022-04-08
# 1118      1344 2022-04-01  2022-04-08
# 1119      1344 2022-04-01  2022-04-08
#
# [1120 rows x 8 columns]

# %%
result.to_excel('oslo.xlsx', index = False) 
result
# Out:
#                 Compagnie Total d'escales        Prix         Duree  \
# 0                Aeroflot       \ndirect     \n427 €    \n3h 50min
# 1              Air France       \ndirect     \n427 €    \n4h 05min
# 2                     LOT     \n1 escale     \n228 €    \n5h 40min
# 3                 Finnair     \n1 escale     \n228 €    \n5h 35min
# 4                Aeroflot       \ndirect     \n427 €    \n4h 00min
# ..                    ...             ...         ...           ...
# 435              Aeroflot     \n1 escale   \n3 171 €    \n7h 15min
# 436     Brussels Airlines     \n1 escale     \n329 €    \n5h 55min
# 437                   LOT     \n1 escale     \n329 €   \n14h 15min
# 438  Plusieurs compagnies     \n1 escale   \n1 584 €    \n5h 55min
# 439  Plusieurs compagnies     \n1 escale   \n1 584 €    \n7h 50min
#
#     Destination  Distance Date_aller Date_retour
# 0        Moscou   2486.34 2022-04-01  2022-04-08
# 1        Moscou   2486.34 2022-04-01  2022-04-08
# 2        Moscou   2486.34 2022-04-01  2022-04-08
# 3        Moscou   2486.34 2022-04-01  2022-04-08
# 4        Moscou   2486.34 2022-04-01  2022-04-08
# ..          ...       ...        ...         ...
# 435      Moscou   2486.34 2022-04-01  2022-04-08
# 436      Moscou   2486.34 2022-04-01  2022-04-08
# 437      Moscou   2486.34 2022-04-01  2022-04-08
# 438      Moscou   2486.34 2022-04-01  2022-04-08
# 439      Moscou   2486.34 2022-04-01  2022-04-08
#
# [440 rows x 8 columns]

# %%
fichiers = ["C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/oslo.xlsx", "C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/oslo_2.xlsx","C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/moscou.xlsx","C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/madrid.xlsx","C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/madrid_2.xlsx", "C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/londres.xlsx","C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/londres_1.xlsx", "C:/Users/bombi/OneDrive/Documents/Fichiers_Scrappes/athenes.xlsx"]
fichier_combine= pd.DataFrame()

for fichier in fichiers:
    df=pd.read_excel(fichier)
    fichier_combine= fichier_combine.append(df, ignore_index= True)

# %%
fichier_combine
# Out:
#                Compagnie Total d'escales        Prix        Duree Destination  \
# 0             Air France       \ndirect     \n204 €   \n2h 20min         Oslo
# 1             Air France       \ndirect     \n204 €   \n2h 30min         Oslo
# 2                Flyr AS       \ndirect     \n195 €   \n2h 25min         Oslo
# 3                Flyr AS       \ndirect     \n195 €   \n2h 25min         Oslo
# 4              Norwegian       \ndirect     \n186 €   \n2h 20min         Oslo
# ...                  ...             ...         ...          ...         ...
# 61343   Turkish Airlines     \n1 escale     \n294 €   \n7h 20min      Athenes
# 61344        Sky Express       \ndirect   \n1 874 €   \n3h 00min      Athenes
# 61345              SWISS     \n1 escale   \n1 874 €   \n5h 30min      Athenes
# 61346        Sky Express       \ndirect   \n1 879 €   \n3h 00min      Athenes
# 61347          Lufthansa     \n1 escale   \n1 879 €   \n4h 55min      Athenes
#
#        Distance Date_aller Date_retour
# 0       1344.00 2022-04-01  2022-04-08
# 1       1344.00 2022-04-01  2022-04-08
# 2       1344.00 2022-04-01  2022-04-08
# 3       1344.00 2022-04-01  2022-04-08
# 4       1344.00 2022-04-01  2022-04-08
# ...         ...        ...         ...
# 61343   2095.52 2022-06-10  2022-06-17
# 61344   2095.52 2022-06-10  2022-06-17
# 61345   2095.52 2022-06-10  2022-06-17
# 61346   2095.52 2022-06-10  2022-06-17
# 61347   2095.52 2022-06-10  2022-06-17
#
# [61348 rows x 8 columns]

# %%
#fichier_combine.to_excel('fich-comb.xlsx')

# %%
df_final = fichier_combine

# %%
df_final
# Out:
#                Compagnie Total d'escales        Prix        Duree Destination  \
# 0             Air France       \ndirect     \n204 €   \n2h 20min         Oslo
# 1             Air France       \ndirect     \n204 €   \n2h 30min         Oslo
# 2                Flyr AS       \ndirect     \n195 €   \n2h 25min         Oslo
# 3                Flyr AS       \ndirect     \n195 €   \n2h 25min         Oslo
# 4              Norwegian       \ndirect     \n186 €   \n2h 20min         Oslo
# ...                  ...             ...         ...          ...         ...
# 61343   Turkish Airlines     \n1 escale     \n294 €   \n7h 20min      Athenes
# 61344        Sky Express       \ndirect   \n1 874 €   \n3h 00min      Athenes
# 61345              SWISS     \n1 escale   \n1 874 €   \n5h 30min      Athenes
# 61346        Sky Express       \ndirect   \n1 879 €   \n3h 00min      Athenes
# 61347          Lufthansa     \n1 escale   \n1 879 €   \n4h 55min      Athenes
#
#        Distance Date_aller Date_retour
# 0       1344.00 2022-04-01  2022-04-08
# 1       1344.00 2022-04-01  2022-04-08
# 2       1344.00 2022-04-01  2022-04-08
# 3       1344.00 2022-04-01  2022-04-08
# 4       1344.00 2022-04-01  2022-04-08
# ...         ...        ...         ...
# 61343   2095.52 2022-06-10  2022-06-17
# 61344   2095.52 2022-06-10  2022-06-17
# 61345   2095.52 2022-06-10  2022-06-17
# 61346   2095.52 2022-06-10  2022-06-17
# 61347   2095.52 2022-06-10  2022-06-17
#
# [61348 rows x 8 columns]
